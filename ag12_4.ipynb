# %%
queue = []

queue.append("A")
queue.append("B")
queue.append("C")

print(queue)
# Out:
# ['A', 'B', 'C']

# %%
queue = ["A", "B", "C"]

print(queue[0]) # ["A", "B", "C"]
print(queue[1:])

print(queue[1])
print(queue[2:])

print(queue[2])
print(queue[3:])
# Out:
# A
# ['B', 'C']
# B
# ['C']
# C
# []

# %%
queue = ["A", "B", "C"]

pop_index = 0

while pop_index < len(queue):
    print(queue[pop_index]) # ["A", "B", "C"]
    print(queue[pop_index+1:])
    pop_index += 1

print(queue)
# Out:
# A
# ['B', 'C']
# B
# ['C']
# C
# []
# ['A', 'B', 'C']
